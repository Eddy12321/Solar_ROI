# %% [markdown]
# # Explorative Data Analysis <a id='Explorative_Data_Analysis'></a>

# %% [markdown]
# ### 1 Table of Contents<a id='Contents'></a>
# * [Explorative Data Analysis](#Explorative_Data_Analysis)
#   * [1 Contents](#Contents)
#   * [2 Introduction](#2_Introduction)
#       * [2.1 Recap](#2.1_Recap)
#       * [2.2 Next Steps](#2.2_Next_Steps)
#   * [3 Imports](#3_Imports)
#   * [4 Load Data](#4_Load_Data)
#   * [5 Looking at the Data](#5_Looking_at_the_Data)

# %% [markdown]
# ### 2 Introduction<a id='2_Introduction'></a>

# %% [markdown]
# #### 2.1 Recap<a id='2.1_Recap'></a>

# %% [markdown]
# m

# %% [markdown]
# #### 2.2 Next Steps<a id='2.2_Next_Steps'></a>

# %% [markdown]
# m

# %% [markdown]
# ### 3 Imports<a id='3_Imports'></a>

# %%
#import warnings
#warnings.simplefilter('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import scale
import pandas_profiling
from library.sb_utils import save_file
import os
import csv

# %% [markdown]
# ### 4 Load Data<a id='4_Load_Data'></a>

# %%
YMCA = pd.read_csv('../data/YMCA.csv')
ForestRoad = pd.read_csv('../data/ForestRoad.csv')
MapDriveEast = pd.read_csv('../data/MapleDriveEast.csv')
UK_data = pd.read_csv('../data/UK_data.csv')

# %% [markdown]
# The UK_data is the combination of data from all three sites: YMCA, Forest Road, and Maple Drive East.

# %% [markdown]
# ### 5 Looking at the Data<a id='5_Looking_at_the_Data'></a>

# %%
UK_data.head()
# Out:
#    Site  TempOut  HiTemp  LowTemp  OutHum  DewPt  WindSpeed  WindRun  HiSpeed  \
# 0  YMCA     14.1    14.2     14.1    91.0   12.6          0      0.0        0
# 1  YMCA     14.1    14.1     14.1    91.0   12.7          0      0.0        2
# 2  YMCA     14.4    14.4     14.1    91.0   12.9          0      0.0        2
# 3  YMCA     15.1    15.1     14.4    86.0   12.7          0      0.0        2
# 4  YMCA     16.0    16.0     15.1    77.0   12.0          0      0.0        1
#
#    WindChill  HeatIndex  THWIndex    Bar  Rain  RainRate  SolarRad  \
# 0       14.1       14.1      14.1  755.5   0.0       0.0      11.0
# 1       14.1       14.2      14.2  755.5   0.0       0.0      23.0
# 2       14.4       14.4      14.4  755.7   0.0       0.0      34.0
# 3       15.1       15.1      15.1  755.8   0.0       0.0      57.0
# 4       16.0       15.9      15.9  756.2   0.0       0.0      56.0
#
#    SolarEnergy  HiSolarRad  P_GEN
# 0         0.47        18.0  0.014
# 1         0.99        26.0  0.067
# 2         1.46        81.0  0.216
# 3         2.45       137.0  0.256
# 4         2.41       192.0  0.284

# %%
UK_data.describe().T
# Out:
#                count        mean         std    min      25%      50%  \
# TempOut      11846.0   17.354001    4.015850    1.1   14.600   17.200
# HiTemp       11846.0   17.582213    4.093306    1.1   14.700   17.400
# min       0.000000     0.000000     0.001000
# 25%       0.000000     0.000000     0.002000
# 50%       1.680000    53.000000     0.088000
# 75%       9.200000   330.000000     0.733000
# max      42.400000  1285.000000     3.008000

# %%
MapDriveEast.describe()
# Out:
#            TempOut       HiTemp      LowTemp       OutHum        DewPt  \
# count  2579.000000  2579.000000  2579.000000  2579.000000  2579.000000
# mean     17.083172    17.261380    16.702947    77.119426    12.714928
# std       4.171216     4.244444     4.153739    14.288060     2.721704
# min       1.100000     1.100000     0.900000    41.000000     0.200000
# 25%      14.100000    14.300000    13.800000    66.000000    11.000000
# 50%      17.200000    17.300000    16.800000    79.000000    12.800000
# 75%      20.100000    20.300000    19.650000    90.000000    14.800000
# max      27.100000    27.100000    26.800000    98.000000    20.100000
#
#          WindSpeed      WindRun      HiSpeed    WindChill    HeatIndex  \
# count  2579.000000  2579.000000  2579.000000  2579.000000  2579.000000
# mean      1.054672     0.527336     4.431950    17.073788    17.148197
# std       1.527520     0.763760     4.232425     4.181198     4.209938
# min       0.000000     0.000000     0.000000     1.100000     1.000000
# 25%       0.000000     0.000000     1.000000    14.100000    14.100000
# 50%       0.000000     0.000000     3.000000    17.200000    17.300000
# 75%       2.000000     1.000000     7.000000    20.100000    20.100000
# max       8.000000     4.000000    25.000000    27.100000    28.000000
#
#           THWIndex          Bar    Rain  RainRate     SolarRad  SolarEnergy  \
# count  2579.000000  2579.000000  2579.0    2579.0  2579.000000  2579.000000
# mean     17.138348   759.240597     0.0       0.0   129.357891     5.563222
# std       4.220825     6.204487     0.0       0.0   162.772789     7.000017
# min       1.000000   739.500000     0.0       0.0     0.000000     0.000000
# 25%      14.100000   755.900000     0.0       0.0    24.000000     1.030000
# 50%      17.300000   760.400000     0.0       0.0    67.000000     2.880000
# 75%      20.100000   763.700000     0.0       0.0   155.500000     6.690000
# max      28.000000   769.200000     0.0       0.0   887.000000    38.150000
#
#         HiSolarRad        P_GEN
# count  2579.000000  2579.000000
# mean    217.505235     1.000770
# std     252.279003     0.912627
# min       0.000000     0.000000
# 25%      32.500000     0.234000
# 50%     102.000000     0.717000
# 75%     331.000000     1.574000
# max     995.000000     3.884000

# %% [markdown]
# Their statistics are fairly similar,

# %%
def scatterplots(columns, ncol=None, figsize=(15, 8)):
    if ncol is None:
        ncol = len(columns)
    nrow = int(np.ceil(len(columns) / ncol))
    fig, axes = plt.subplots(nrow, ncol, figsize=figsize, squeeze=False)
    fig.subplots_adjust(wspace=0.5, hspace=0.6)
    for i, col in enumerate(columns):
        ax = axes.flatten()[i]
        ax.scatter(x = col, y = 'P_GEN', data=UK_data, alpha=0.5)
        ax.set(xlabel=col, ylabel='Power Generated')
    nsubplots = nrow * ncol    
    for empty in range(i+1, nsubplots):
        axes.flatten()[empty].set_visible(False)
